# %%
import pandas as pd

# %%
dicionario = pd.DataFrame([
    {
        "variavel": "Age",
        "descricao": "idade do indivíduo",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "Gender",
        "descricao": "gênero do indivíduo",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "Height",
        "descricao": "altura do indiíduo",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "Weight",
        "descricao": "peso do indivíduo",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "CALC",
        "descricao": "frequência do consumo de álcool pelo indivíduo",
        "tipo": "qualitativa",
        "subtipo": "ordinal"
    },{
        "variavel": "FAVC",
        "descricao": "indica se o indivíduo consome comidas altamentes calóricas com frequência",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "FCVC",
        "descricao": "indica o nível de consumo de vegetais nas refeições do indivíduo",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },{
        "variavel": "NCP",
        "descricao": "quantas refeições principais o indivíduo faz diariamente",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "SCC",
        "descricao": "indica se o indivíduo monitora as calorias ingeridas diariamente",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "SMOKE",
        "descricao": "indica se o indivíduo fuma ou não",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "CH2O",
        "descricao": "quanta água o indivíduo consome diariamente",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "family_history_with_overweight",
        "descricao": "indica se algum membro da família do indivídio sofreu ou sofre com excesso de peso",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "FAF",
        "descricao": "quão frequentemente o indivíduo pratica atividades físicas",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "TUE",
        "descricao": "quanto tempo o indivíduo passa usando dispositivos tecnológicos",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },{
        "variavel": "CAEC",
        "descricao": "frequência em que o indivíduo come algum alimento entre as refeições",
        "tipo": "qualitativa",
        "subtipo": "ordinal"
    },{
        "variavel": "MTRANS",
        "descricao": "tipo de transporte que o indivíduo costuma usar",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "NObeyesdad",
        "descricao": "nível de obesidade do indivíduo",
        "tipo": "qualitativa",
        "subtipo": "ordinal"
    }
])

# %%
dicionario.to_csv('../data/external/dictionary.csv', index=False)
dicionario
# Out:
#                           variavel  \
# 0                              Age
# 1                           Gender
# 2                           Height
# 3                           Weight
# 4                             CALC
# 5                             FAVC
# 6                             FCVC
# 7                              NCP
# 8                              SCC
# 9                            SMOKE
# 10                            CH2O
# 11  family_history_with_overweight
# 12                             FAF
# 13                             TUE
# 14                            CAEC
# 15                          MTRANS
# 16                      NObeyesdad
#
#                                             descricao          tipo   subtipo
# 0                                  idade do indivíduo  quantitativa  contínua
# 1                                 gênero do indivíduo   qualitativa   nominal
# 2                                  altura do indiíduo  quantitativa  contínua
# ...
